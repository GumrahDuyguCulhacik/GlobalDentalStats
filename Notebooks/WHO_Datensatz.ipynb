# %% [markdown]
# ## Projektbeschreibung
# Im Rahmen dieses Projekts wurden die im Abschnitt „Dental Indicators“ der Weltgesundheitsorganisation (WHO) veröffentlichten Datensätze im CSV‑Format untersucht.
# Nach der Analyse wurden die für die Studie geeigneten Datensätze ausgewählt und anhand der relevanten Variablen zusammengeführt.
#
# Durch die Kombination verschiedener Datensätze wurde eine aussagekräftigere, nutzbare und ganzheitliche Datenstruktur für die Analyse erstellt.

# %%
import pandas as pd
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\User Laptop\Desktop\Projekt_\projekt_dental\notebooks

# %%
df1 = pd.read_excel("../data/raw_data/dental_healthcarei_inMillion_total_expenditure.xlsx")
df2 = pd.read_excel("../data/raw_data/number_of_labour_days_needed_to_buy_annual_support_of_fluoride_tootthpaste_perPerson.xlsx")
df3 = pd.read_excel("../data/raw_data/perCapita_expenditure_on_dentalhealth.xlsx")
df4 = pd.read_excel("../data/raw_data/prevalence_of_edentulism_in_people20+.xlsx")
df5 = pd.read_excel("../data/raw_data/prevalence_of_severe_peridontal_disease_in_people15+.xlsx")
df6 = pd.read_excel("../data/raw_data/Prevalence_of_untreated_caries_of_permanenet_teetf_5+.xlsx")
df7 = pd.read_excel("../data/raw_data/urgent_treatment_for_providing_emergency_oral_care_pain.xlsx")

# %%
df8 = pd.read_excel("../data/raw_data/affordability_of_fluoride_toothpaste.xlsx")
df9 = pd.read_excel("../data/raw_data/dental_assistants_therapists_num.xlsx")
df10 = pd.read_excel("../data/raw_data/dental_prosthetic_technicians_per10000popul.xlsx")
df11 = pd.read_excel("../data/raw_data/dentists_per_10000population.xlsx")
df12 = pd.read_excel("../data/raw_data/lip_and_oral_cavity_cancer2020.xlsx")
df13 = pd.read_excel("../data/raw_data/prevelence_of_untreated_caries_of_deciduous_teeth_in_children_1_9.xlsx")
df14 = pd.read_excel("../data/raw_data/total_productivity_lossess_due_to_5_oral_diseases.xlsx")

# %%
df1.head(2)
# Out:
#   Applied filters:\nLocation type is Country\nLANGUAGE_CODE is en\nIndicatorCode is ORALHEALTH_DENTALHEALTHCARE_EXP_TOTAL  \
# 0                                                NaN
# 1                                      IndicatorCode
#
#   Unnamed: 1 Unnamed: 2          Unnamed: 3      Unnamed: 4     Unnamed: 5  \
# 0        NaN        NaN                 NaN             NaN            NaN
# 1  Indicator  ValueType  ParentLocationCode  ParentLocation  Location type
#
#             Unnamed: 6 Unnamed: 7   Unnamed: 8 Unnamed: 9  ...   Unnamed: 24  \
# 0                  NaN        NaN          NaN        NaN  ...           NaN
# 1  SpatialDimValueCode   Location  Period type     Period  ...  FactValueUoM
#
#                  Unnamed: 25          Unnamed: 26                 Unnamed: 27  \
# 0                        NaN                  NaN                         NaN
# 1  FactValueNumericLowPrefix  FactValueNumericLow  FactValueNumericHighPrefix
#
# ...

# %%
cleaned_dfs = {}

for i in range(1, 15):
    df = globals()[f'df{i}']  
    new_columns = df.iloc[1]
    df_cleaned = df.iloc[2:].copy()
    df_cleaned.columns = new_columns
    df_cleaned.reset_index(drop=True, inplace=True)
    
    # Sowohl dem Wörterbuch hinzufügen als auch den Originalnamen aktualisieren
    cleaned_dfs[f'df{i}'] = df_cleaned
    globals()[f'df{i}'] = df_cleaned

# %%
df1.shape
# Out:
# (192, 34)

# %%
df1.head(2)
# Out:
# 1                          IndicatorCode  \
# 0  ORALHEALTH_DENTALHEALTHCARE_EXP_TOTAL
# 1  ORALHEALTH_DENTALHEALTHCARE_EXP_TOTAL
#
# 1                                          Indicator ValueType  \
# 0  Total expenditure on dental healthcare in mill...   numeric
# 1  Total expenditure on dental healthcare in mill...   numeric
#
# 1 ParentLocationCode ParentLocation Location type SpatialDimValueCode  \
# 0                AFR         Africa       Country                 AGO
# 1                AFR         Africa       Country                 BDI
#
# 1 Location Period type Period  ... FactValueUoM FactValueNumericLowPrefix  \
# 0   Angola        Year   2019  ...          NaN                       NaN
# 1  Burundi        Year   2019  ...          NaN                       NaN
#
# 1 FactValueNumericLow FactValueNumericHighPrefix FactValueNumericHigh Value  \
# 0                 NaN                        NaN                  NaN  70.2
# ...

# %%
for i in range(1, 15):
    print(f'df{i}: {globals()[f"df{i}"].shape}', end=' || ')
# Out:
# df1: (192, 34) || df2: (77, 34) || df3: (192, 34) || df4: (194, 34) || df5: (194, 34) || df6: (194, 34) || df7: (177, 34) || df8: (77, 34) || df9: (496, 34) || df10: (96, 34) || df11: (3105, 34) || df12: (519, 34) || df13: (194, 34) || df14: (192, 34) ||

# %%
df2.head(2)
# Out:
# 1                              IndicatorCode  \
# 0  ORALHEALTH_FLUORIDETOOTHPHASTE_LABOURDAYS
# 1  ORALHEALTH_FLUORIDETOOTHPHASTE_LABOURDAYS
#
# 1                                          Indicator ValueType  \
# 0  Number of labour days needed to buy annual sup...   numeric
# 1  Number of labour days needed to buy annual sup...   numeric
#
# 1 ParentLocationCode ParentLocation Location type SpatialDimValueCode  \
# 0                AFR         Africa       Country                 BEN
# 1                AFR         Africa       Country                 BFA
#
# 1      Location Period type Period  ... FactValueUoM  \
# 0         Benin        Year   2019  ...          NaN
# 1  Burkina Faso        Year   2019  ...          NaN
#
# 1 FactValueNumericLowPrefix FactValueNumericLow FactValueNumericHighPrefix  \
# 0                       NaN                 NaN                        NaN
# 1                       NaN                 NaN                        NaN
#
# ...

# %%
df3.head(2)
# Out:
# 1                           IndicatorCode  \
# 0  ORALHEALTH_DENTALHEALTHCARE_EXP_PERCAP
# 1  ORALHEALTH_DENTALHEALTHCARE_EXP_PERCAP
#
# 1                                          Indicator ValueType  \
# 0  Per capita expenditure on dental healthcare (US$)   numeric
# 1  Per capita expenditure on dental healthcare (US$)   numeric
#
# 1 ParentLocationCode ParentLocation Location type SpatialDimValueCode  \
# 0                AFR         Africa       Country                 AGO
# 1                AFR         Africa       Country                 BDI
#
# 1 Location Period type Period  ... FactValueUoM FactValueNumericLowPrefix  \
# 0   Angola        Year   2019  ...          NaN                       NaN
# 1  Burundi        Year   2019  ...          NaN                       NaN
#
# 1 FactValueNumericLow FactValueNumericHighPrefix FactValueNumericHigh Value  \
# 0                 NaN                        NaN                  NaN   2.3
# ...

# %%
df4.head(2)
# Out:
# 1                     IndicatorCode  \
# 0  ORALHEALTH_EDENTULISM_PREVALENCE
# 1  ORALHEALTH_EDENTULISM_PREVALENCE
#
# 1                                         Indicator ValueType  \
# 0  Prevalence of edentulism in people 20+ years (%)   numeric
# 1  Prevalence of edentulism in people 20+ years (%)   numeric
#
# 1 ParentLocationCode ParentLocation Location type SpatialDimValueCode  \
# 0                AFR         Africa       Country                 AGO
# 1                AFR         Africa       Country                 BDI
#
# 1 Location Period type Period  ... FactValueUoM FactValueNumericLowPrefix  \
# 0   Angola        Year   2019  ...          NaN                       NaN
# 1  Burundi        Year   2019  ...          NaN                       NaN
#
# 1 FactValueNumericLow FactValueNumericHighPrefix FactValueNumericHigh Value  \
# 0                 NaN                        NaN                  NaN   4.0
# ...

# %%
df5.head(2)
# Out:
# 1                        IndicatorCode  \
# 0  ORALHEALTH_SEVEREPERIODONTALDISEASE
# 1  ORALHEALTH_SEVEREPERIODONTALDISEASE
#
# 1                                          Indicator ValueType  \
# 0  Prevalence of severe periodontal disease in pe...   numeric
# 1  Prevalence of severe periodontal disease in pe...   numeric
#
# 1 ParentLocationCode ParentLocation Location type SpatialDimValueCode  \
# 0                AFR         Africa       Country                 AGO
# 1                AFR         Africa       Country                 BDI
#
# 1 Location Period type Period  ... FactValueUoM FactValueNumericLowPrefix  \
# 0   Angola        Year   2019  ...          NaN                       NaN
# 1  Burundi        Year   2019  ...          NaN                       NaN
#
# 1 FactValueNumericLow FactValueNumericHighPrefix FactValueNumericHigh Value  \
# 0                 NaN                        NaN                  NaN  23.9
# ...

# %%
df6.head(2)
# Out:
# 1                        IndicatorCode  \
# 0  ORALHEALTH_UNTREATEDCARIESPERMANENT
# 1  ORALHEALTH_UNTREATEDCARIESPERMANENT
#
# 1                                          Indicator ValueType  \
# 0  Prevalence of untreated caries of permanent te...   numeric
# 1  Prevalence of untreated caries of permanent te...   numeric
#
# 1 ParentLocationCode ParentLocation Location type SpatialDimValueCode  \
# 0                AFR         Africa       Country                 AGO
# 1                AFR         Africa       Country                 BDI
#
# 1 Location Period type Period  ... FactValueUoM FactValueNumericLowPrefix  \
# 0   Angola        Year   2019  ...          NaN                       NaN
# 1  Burundi        Year   2019  ...          NaN                       NaN
#
# 1 FactValueNumericLow FactValueNumericHighPrefix FactValueNumericHigh Value  \
# 0                 NaN                        NaN                  NaN  27.2
# ...

# %%
df7.head(2)
# Out:
# 1                       IndicatorCode  \
# 0  ORALHEALTH_AVAILABILITY_URGENTCARE
# 1  ORALHEALTH_AVAILABILITY_URGENTCARE
#
# 1                                          Indicator ValueType  \
# 0  Oral health: Urgent treatment for providing em...      text
# 1  Oral health: Urgent treatment for providing em...      text
#
# 1 ParentLocationCode ParentLocation Location type SpatialDimValueCode  \
# 0                AFR         Africa       Country                 AGO
# 1                AFR         Africa       Country                 BDI
#
# 1 Location Period type Period  ... FactValueUoM FactValueNumericLowPrefix  \
# 0   Angola        Year   2021  ...          NaN                       NaN
# 1  Burundi        Year   2021  ...          NaN                       NaN
#
# 1 FactValueNumericLow FactValueNumericHighPrefix FactValueNumericHigh  \
# 0                 NaN                        NaN                  NaN
# 1                 NaN                        NaN                  NaN
#
# ...

# %%
df7["Period"].value_counts()
# Out:
# Period
# 2021    177
# Name: count, dtype: int64

# %%
df8.head(2)
# Out:
# 1                                IndicatorCode  \
# 0  ORALHEALTH_AFFORDABILITY_FLUORIDETOOTHPASTE
# 1  ORALHEALTH_AFFORDABILITY_FLUORIDETOOTHPASTE
#
# 1                             Indicator ValueType ParentLocationCode  \
# 0  Affordability of fluoride toothpaste      text                AFR
# 1  Affordability of fluoride toothpaste      text                AFR
#
# 1 ParentLocation Location type SpatialDimValueCode      Location Period type  \
# 0         Africa       Country                 BEN         Benin        Year
# 1         Africa       Country                 BFA  Burkina Faso        Year
#
# 1 Period  ... FactValueUoM FactValueNumericLowPrefix FactValueNumericLow  \
# 0   2019  ...          NaN                       NaN                 NaN
# 1   2019  ...          NaN                       NaN                 NaN
#
# 1 FactValueNumericHighPrefix FactValueNumericHigh         Value  \
# 0                        NaN                  NaN  Unaffordable
# ...

# %%
df9.head(2)
# Out:
# 1 IndicatorCode                                  Indicator ValueType  \
# 0      HWF_0012  Dental Assistants and Therapists (number)   numeric
# 1      HWF_0012  Dental Assistants and Therapists (number)   numeric
#
# 1 ParentLocationCode ParentLocation Location type SpatialDimValueCode  \
# 0                AFR         Africa       Country                 AGO
# 1                AFR         Africa       Country                 BEN
#
# 1 Location Period type Period  ... FactValueUoM FactValueNumericLowPrefix  \
# 0   Angola        Year   2022  ...          NaN                       NaN
# 1    Benin        Year   2022  ...          NaN                       NaN
#
# 1 FactValueNumericLow FactValueNumericHighPrefix FactValueNumericHigh Value  \
# 0                 NaN                        NaN                  NaN   796
# 1                 NaN                        NaN                  NaN     7
#
# 1 FactValueTranslationID                                       FactComments  \
# ...

# %%
df9["Period"].value_counts()
# Out:
# Period
# 2019    63
# 2022    51
# 2018    46
# 2020    39
# 2021    37
# 2023    29
# 2004    24
# 2017    22
# 2016    18
# 2008    16
# 2015    15
# 2010    14
# 2009    14
# 2014    12
# 2012    12
# 2011    11
# 2007     9
# 2013     8
# 2002     7
# 2006     6
# 2001     5
# 2005     5
# 2000     5
# 2003     3
# 1995     3
# 1992     2
# 1997     2
# 1991     2
# 1988     2
# 1998     2
# 1996     2
# 1987     1
# 1984     1
# 1985     1
# 1986     1
# 1994     1
# 1989     1
# 1990     1
# 1993     1
# 1999     1
# 1983     1
# Name: count, dtype: int64

# %%
df10.head(2)
# Out:
# 1                            IndicatorCode  \
# 0  ORALHEALTH_HWF_DENTALPROSTHETICTECH_10K
# 1  ORALHEALTH_HWF_DENTALPROSTHETICTECH_10K
#
# 1                                          Indicator ValueType  \
# 0  Dental prosthetic technicians (per 10 000 popu...   numeric
# 1  Dental prosthetic technicians (per 10 000 popu...   numeric
#
# 1 ParentLocationCode ParentLocation Location type SpatialDimValueCode  \
# 0                AFR         Africa       Country                 BEN
# 1                AFR         Africa       Country                 BFA
#
# 1      Location Period type     Period  ... FactValueUoM  \
# 0         Benin        Year  2014-2019  ...          NaN
# 1  Burkina Faso        Year  2014-2019  ...          NaN
#
# 1 FactValueNumericLowPrefix FactValueNumericLow FactValueNumericHighPrefix  \
# 0                       NaN                 NaN                        NaN
# 1                       NaN                 NaN                        NaN
#
# ...

# %%
df10["Period"].value_counts()
# Out:
# Period
# 2014-2019    96
# Name: count, dtype: int64

# %%
df11.head(3)
# Out:
# 1 IndicatorCode              Indicator ValueType ParentLocationCode  \
# 0      HWF_0010  Dentists (per 10,000)   numeric                AFR
# 1      HWF_0010  Dentists (per 10,000)   numeric                AFR
# 2      HWF_0010  Dentists (per 10,000)   numeric                AFR
#
# 1 ParentLocation Location type SpatialDimValueCode Location Period type  \
# 0         Africa       Country                 AGO   Angola        Year
# 1         Africa       Country                 AGO   Angola        Year
# 2         Africa       Country                 AGO   Angola        Year
#
# 1 Period  ... FactValueUoM FactValueNumericLowPrefix FactValueNumericLow  \
# 0   2022  ...          NaN                       NaN                 NaN
# 1   2018  ...          NaN                       NaN                 NaN
# 2   2004  ...          NaN                       NaN                 NaN
#
# 1 FactValueNumericHighPrefix FactValueNumericHigh Value  \
# ...

# %%
df11["Period"].dtype
# Out:
# dtype('O')

# %%
(df11['Period'] == "2019").sum()
# Out:
# 129

# %%
df12.head(10)
# Out:
# 1                                    IndicatorCode  \
# 0  ORAL_HEALTH_CANCER_LIPORALCAVITY_NEWCASE_NUMBER
# 1  ORAL_HEALTH_CANCER_LIPORALCAVITY_NEWCASE_NUMBER
# 2  ORAL_HEALTH_CANCER_LIPORALCAVITY_NEWCASE_NUMBER
# 3  ORAL_HEALTH_CANCER_LIPORALCAVITY_NEWCASE_NUMBER
# 4  ORAL_HEALTH_CANCER_LIPORALCAVITY_NEWCASE_NUMBER
# 5  ORAL_HEALTH_CANCER_LIPORALCAVITY_NEWCASE_NUMBER
# 6  ORAL_HEALTH_CANCER_LIPORALCAVITY_NEWCASE_NUMBER
# 7  ORAL_HEALTH_CANCER_LIPORALCAVITY_NEWCASE_NUMBER
# 8  ORAL_HEALTH_CANCER_LIPORALCAVITY_NEWCASE_NUMBER
# 9  ORAL_HEALTH_CANCER_LIPORALCAVITY_NEWCASE_NUMBER
#
# 1                                          Indicator ValueType  \
# 0  Number of new cases of lip and oral cavity cancer   numeric
# 1  Number of new cases of lip and oral cavity cancer   numeric
# 2  Number of new cases of lip and oral cavity cancer   numeric
# 3  Number of new cases of lip and oral cavity cancer   numeric
# 4  Number of new cases of lip and oral cavity cancer   numeric
# ...

# %%
df12["label"] =  df12.groupby("Location").cumcount().map({0: "TotalCancerNewCases", 1: "MaleCancerNewCases", 2: "FemaleCancerNewCases"})

df_wide= df12.pivot(index= "Location", columns= "label", values= "Value").reset_index()

df_wide.columns.name= None

df_wide.head()
# Out:
#       Location FemaleCancerNewCases MaleCancerNewCases TotalCancerNewCases
# 0  Afghanistan                  295                618                 913
# 1      Albania                   48                 58                 106
# 2      Algeria                  107                186                 293
# 3       Angola                  166                316                 482
# 4    Argentina                  414                890               1 304

# %%
df13.head(2)
# Out:
# 1                        IndicatorCode  \
# 0  ORALHEALTH_UNTREATEDCARIESDECIDUOUS
# 1  ORALHEALTH_UNTREATEDCARIESDECIDUOUS
#
# 1                                          Indicator ValueType  \
# 0  Prevalence of untreated caries of deciduous te...   numeric
# 1  Prevalence of untreated caries of deciduous te...   numeric
#
# 1 ParentLocationCode ParentLocation Location type SpatialDimValueCode  \
# 0                AFR         Africa       Country                 AGO
# 1                AFR         Africa       Country                 BDI
#
# 1 Location Period type Period  ... FactValueUoM FactValueNumericLowPrefix  \
# 0   Angola        Year   2019  ...          NaN                       NaN
# 1  Burundi        Year   2019  ...          NaN                       NaN
#
# 1 FactValueNumericLow FactValueNumericHighPrefix FactValueNumericHigh Value  \
# 0                 NaN                        NaN                  NaN  37.8
# ...

# %%
df14.head(2)
# Out:
# 1                     IndicatorCode  \
# 0  ORALHEALTH_PRODLOSS_ORALDISEASES
# 1  ORALHEALTH_PRODLOSS_ORALDISEASES
#
# 1                                          Indicator ValueType  \
# 0  Total productivity losses due to 5 oral diseas...   numeric
# 1  Total productivity losses due to 5 oral diseas...   numeric
#
# 1 ParentLocationCode ParentLocation Location type SpatialDimValueCode  \
# 0                AFR         Africa       Country                 AGO
# 1                AFR         Africa       Country                 BDI
#
# 1 Location Period type Period  ... FactValueUoM FactValueNumericLowPrefix  \
# 0   Angola        Year   2019  ...          NaN                       NaN
# 1  Burundi        Year   2019  ...          NaN                       NaN
#
# 1 FactValueNumericLow FactValueNumericHighPrefix FactValueNumericHigh  Value  \
# 0                 NaN                        NaN                  NaN  195.8
# ...

# %%
df1_renamed = df1[['Location', 'Period', 'Value']].rename(columns={'Value': 'TotalExpenditure'})
df3_renamed = df3[['Location', 'Period', 'Value']].rename(columns={'Value': 'PerCapitaExpenditure'})
df4_renamed = df4[['Location', 'Period', 'Value']].rename(columns={'Value': 'EdentulismRate'})
df5_renamed = df5[['Location', 'Period', 'Value']].rename(columns={'Value': 'PeriodontalRate'})
df6_renamed = df6[['Location', 'Period', 'Value']].rename(columns={'Value': 'UntreatedCariesRate'})
df13_renamed = df13[['Location', 'Period', 'Value']].rename(columns={'Value': 'UntreatedDeciduousCaries1_9Rate'})
df14_renamed = df14[['Location', 'Period', 'Value']].rename(columns={'Value': 'ProductivityLoss'})


merged_df = df1_renamed.merge(df3_renamed, on=['Location', 'Period'])
merged_df = merged_df.merge(df4_renamed, on=['Location', 'Period'])
merged_df = merged_df.merge(df5_renamed, on=['Location', 'Period'])
merged_df = merged_df.merge(df6_renamed, on=['Location', 'Period'])
merged_df = merged_df.merge(df13_renamed, on=['Location', 'Period'])
merged_df = merged_df.merge(df14_renamed, on=['Location', 'Period'])

merged_df = merged_df.merge(df_wide, on='Location', how='left')

# %%
merged_df.head()
# Out:
#        Location Period TotalExpenditure PerCapitaExpenditure EdentulismRate  \
# 0        Angola   2019             70.2                  2.3            4.0
# 1       Burundi   2019              1.3                  0.1            2.0
# 2         Benin   2019              3.3                  0.3            2.9
# 3  Burkina Faso   2019              4.6                  0.2            1.9
# 4      Botswana   2019             57.4                 24.1            7.5
#
#   PeriodontalRate UntreatedCariesRate UntreatedDeciduousCaries1_9Rate  \
# 0            23.9                27.2                            37.8
# 1            19.2                31.7                            41.6
# 2            27.1                29.5                            39.6
# 3            27.4                27.5                            40.3
# 4            26.3                32.7                            37.6
#
#   ProductivityLoss FemaleCancerNewCases MaleCancerNewCases TotalCancerNewCases
# ...

# %%
merged_df.shape
# Out:
# (192, 12)

# %%
#merged_df.to_excel("agizsagligi.xlsx", index=False)

# %%
merged_df.columns
# Out:
# Index(['Location', 'Period', 'TotalExpenditure', 'PerCapitaExpenditure',
#        'EdentulismRate', 'PeriodontalRate', 'UntreatedCariesRate',
#        'UntreatedDeciduousCaries1_9Rate', 'ProductivityLoss',
#        'FemaleCancerNewCases', 'MaleCancerNewCases', 'TotalCancerNewCases'],
#       dtype='object')
